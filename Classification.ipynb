# %% [markdown]
# <a href="https://colab.research.google.com/github/nibchee/data_science_machine_learning/blob/main/Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.TotalCharges=pd.to_numeric(df.TotalCharges,errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.dropna(how='any',inplace=True)

# %%
df.Churn.value_counts()/len(df) * 100
# Out:
# Churn
# No     73.421502
# Yes    26.578498
# Name: count, dtype: float64

# %%
y=df.Churn.values

# %%
X=df.drop(['customerID','Churn'],axis=1)

# %%
X.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges'],
#       dtype='object')

# %%
#Convert Categoricla into numerical
X=pd.get_dummies(X,columns=['gender', 'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'],drop_first=True)

# %%
X.head(1)
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 0              0       1           29.85         29.85        False
#
#    Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0         True           False             False
#
#    MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 0                            True              False  ...
#
#    StreamingTV_No internet service  StreamingTV_Yes  \
# 0                            False            False
#
#    StreamingMovies_No internet service  StreamingMovies_Yes  \
# 0                                False                False
#
#    Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 0              False              False                  True
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  False                            True
#
#    PaymentMethod_Mailed check
# 0                       False
#
# [1 rows x 30 columns]

# %%
#Splitting Data into training and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.25)

# %%
len(X_train)
# Out:
# 5274

# %%
len(X_test)
# Out:
# 1758

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train_sc=sc.fit_transform(X_train)
X_test_sc=sc.transform(X_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
X_train_sc
# Out:
# array([[-0.44293297, -0.62832622, -0.0819932 , ..., -0.52248501,
#         -0.70288761,  1.81131007],
#        [-0.44293297,  1.32211078,  0.83841516, ..., -0.52248501,
#          1.42270256, -0.55208659],
#        [-0.44293297,  0.99703795,  0.1843094 , ..., -0.52248501,
#         -0.70288761, -0.55208659],
#        ...,
#        [-0.44293297,  1.60654951,  0.54714669, ...,  1.9139305 ,
#         -0.70288761, -0.55208659],
#        [-0.44293297,  0.83450153, -1.52668481, ..., -0.52248501,
#         -0.70288761,  1.81131007],
#        [-0.44293297,  1.03767206,  0.37405   , ..., -0.52248501,
#         -0.70288761,  1.81131007]])

# %% [markdown]
# ###KNN Classifier

# %%
#Call KNN Classifier
from sklearn.neighbors import KNeighborsClassifier

#Initatiating the classifier
model=KNeighborsClassifier()

#Passing data to classifier
model.fit(X_train_sc,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=model.predict(X_test_sc)

# %%
y_test
# Out:
# array(['No', 'Yes', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
y_pred
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
#Classifications metrics=to check how model is behaving
from sklearn.metrics import accuracy_score
round(accuracy_score(y_test,y_pred)*100,2)
# Out:
# 73.78

# %% [markdown]
# ###New Data Prediction

# %%
X_test_sc
# Out:
# array([[-4.51330710e-17,  6.60000000e+01,  9.00500000e+01, ...,
#          1.00000000e+00,  7.74672114e-17, -5.25429782e-17],
#        [-4.51330710e-17,  5.30000000e+01,  9.84000000e+01, ...,
#          1.00000000e+00,  7.74672114e-17, -5.25429782e-17],
#        [-4.51330710e-17,  1.00000000e+00,  2.54000000e+01, ...,
#         -6.73627925e-18,  7.74672114e-17,  1.00000000e+00],
#        ...,
#        [-4.51330710e-17,  7.10000000e+01,  8.06000000e+01, ...,
#         -6.73627925e-18,  7.74672114e-17, -5.25429782e-17],
#        [-4.51330710e-17,  2.20000000e+01,  2.04500000e+01, ...,
#         -6.73627925e-18,  7.74672114e-17, -5.25429782e-17],
#        [-4.51330710e-17,  4.90000000e+01,  7.18000000e+01, ...,
#         -6.73627925e-18,  1.00000000e+00, -5.25429782e-17]])
